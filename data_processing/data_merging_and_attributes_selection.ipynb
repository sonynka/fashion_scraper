# %%
import pandas as pd
import os
import glob
import numpy as np
from shutil import copyfile

# %%
pd.set_option('display.max_colwidth', 1000)

# %% [markdown]
# # Data Merging

# %%
df_about = pd.read_csv('../../../data/aboutyou/data.csv', sep=';', encoding='utf-8')
df_fashion = pd.read_csv('../../../data/fashionid/data.csv', sep=';', encoding='utf-8')
df_zalando = pd.read_csv('../../../data/zalando/data.csv', sep=';', encoding='utf-8')

# %%
print(df_about.shape)
print(df_fashion.shape)
print(df_zalando.shape)
# Out:
# (40477, 10)
# (11857, 10)
# (43413, 9)

# %%
df_zalando['product_url'] = ''

# %%
df_about['data_path'] = 'aboutyou'
df_fashion['data_path'] = 'fashionid'
df_zalando['data_path'] = 'zalando'

# %%
df = df_about.append(df_fashion.append(df_zalando))
df['id'] = df['id'].astype(str)
df.shape
# Out:
# (95747, 11)

# %% [markdown]
# # Rename categories

# %%
def translate_attributes(attr, translations):
    for english, german_list in translations.items():
        if any(german in attr for german in german_list):
            return english

# %%
df.category.unique()
# Out:
# array(['blusen-und-tuniken', 'hosen', 'jacken', 'jeans', 'kleider',
#        'roecke', 'shirts', 'strick', 'tops', 'blusen', 'pullover-strick',
#        'blusen-tuniken', 'jacken-maentel', 'pullover-und-strickjacken'], dtype=object)

# %%
category_translation = {
        'tops': ['shirts', 'tops'],
        'pants': ['hosen', 'jeans'],
        'knitwear': ['strick'],
        'jackets': ['jacken'],
        'dresses': ['kleider'],
        'skirts': ['roecke'],
        'blouses': ['blusen'],
        'jumpsuits': ['jumpsuits']}

# %%
df['category_en'] = df['category'].apply(
    lambda x: translate_attributes(x, category_translation))

# %%
df.groupby('category_en')['category'].apply(lambda x: ','.join(x.unique())).reset_index()
# Out:
#   category_en                                          category
# 0     blouses          blusen-und-tuniken,blusen,blusen-tuniken
# 1     dresses                                           kleider
# 2     jackets                             jacken,jacken-maentel
# 3    knitwear  strick,pullover-strick,pullover-und-strickjacken
# 4       pants                                       hosen,jeans
# 5      skirts                                            roecke
# 6        tops                                       shirts,tops

# %%
df['category'] = df['category_en']
df = df.drop('category_en', axis=1)

# %% [markdown]
# # Attributes Selection

# %% [markdown]
# ## Attributes Analysis
# Loads the data.csv file and prints the most common attributes (tags). Then creates columns for the selected attributes and converts them to dummy variables.

# %%
df.describe()
# Out:
#                  img_path  \
# count               95747
# unique              95747
# top     jeans/9733029.jpg
# freq                    1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      attributes  \
# count                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     95747
# unique                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    93515
# top     Material & Pflegehinweise, Material Oberstoff: 100% Polyester, Futter: 100% Polyester, Materialkonstruktion: Gehäkelt, Pflegehinweise: Handwäsche, chemische Reinigung möglich, Mehr zu diesem Produkt, Stark transparente Partien, Kragen: Stehkragen, Verschluss: Reißverschluss, Muster: Unifarben, Details: Unterrock, Artikelnummer: TRF21C01O-J11, Modelgröße: Unser Model ist 178 cm groß und trägt Größe 38, Ärmellänge: Ärmellos, Jackenlänge: 40 cm bei Größe 38, Rückenbreite: 31 cm bei Größe 38, Kostenloser Versand & Rückversand, 100 Tage Rückgaberecht
# freq                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          3
#
#         brand category  color             id  \
# count   95747    95747  95747          95747
# unique   1089        7      9          92220
# top      ONLY     tops   blue  IV521C00D-A11
# freq     3700    20085  25904              3
#
#                                                                   img_url  \
# count                                                               95747
# unique                                                              91857
# top     https://cdn.aboutstatic.com/file/88c3ad5d2d588801af19a8b057897a97
# freq                                                                    4
#
#                                                                                                                                                                                                                                                                     model_img_urls  \
# count                                                                                                                                                                                                                                                                        95486
# unique                                                                                                                                                                                                                                                                       91645
# top     https://cdn.aboutstatic.com/file/316fb99a2c7bb3da037a19e6205bddab, https://cdn.aboutstatic.com/file/9674e396443058c9a7d26bc24a0b6a4f, https://cdn.aboutstatic.com/file/5e732d1ddeed898836cb8f89d9663655, https://cdn.aboutstatic.com/file/9e7f7904e8751e667930f63308c989ae
# freq                                                                                                                                                                                                                                                                             3
#
#          name product_url data_path
# count   95747       95747     95747
# unique  40264       48974         3
# top     Bluse               zalando
# freq     3339       43413     43413

# %%
# delete rows that belong to 2 categories
df = df.groupby('id').first().reset_index()

# %%
df['tags'] = df['attributes'].apply(lambda x: [t.strip() for t in x.lower().split(',')])

# %% [markdown]
# Get count for each of the tags, if it appears in the attributes list of any of the images.

# %%
tag_count = {}
def count_tags(tags):
    for tag in tags:
        t = tag.lower()
        if t in tag_count:
            tag_count[t] += 1
        else:
            tag_count[t] = 1
            
a = df['tags'].apply(count_tags)

# %% [markdown]
# Sort by the most used tags and print

# %%
tag_df = pd.Series(tag_count).reset_index().rename(columns={'index': 'tag', 0: 'count'})
num_imgs = df.shape[0]
tag_df['ratio'] = (pd.to_numeric(tag_df['count']) / num_imgs * 100).round(2)
tag_df = tag_df.sort_values('ratio', ascending=False)

# %%
tag_df['tag'].unique().tolist()
# Out:
# ['material & pflegehinweise',
#  '100 tage rückgaberecht',
#  'mehr zu diesem produkt',
#  'kostenloser versand & rückversand',
#  'unifarben',
#  'pflegehinweise:\xa0nicht trockner geeignet',
#  'maschinenwäsche bei 30°c',
#  'passform:\xa0normal',
#  'muster:\xa0unifarben',
#  'passform: normale passform',
#  'schonwaschgang',
#  'weicher griff',
#  'länge:\xa0normale länge',
#  'elastizität: leicht elastisch',
#  'rundhals-ausschnitt',
#  'ausschnitt:\xa0rundhals',
#  'länge: normale länge',
#  'elastizität: nicht elastisch',
#  'ärmellänge:\xa0langarm',
#  'abgesteppter saum/kante',
#  'ton-in-ton-nähte',
#  'ärmellänge: langarm',
#  'jersey',
#  'gerader saum',
#  'all-over-muster',
#  'pflegehinweise:\xa0maschinenwäsche bei 40°c',
#  'material oberstoff:\xa0100% baumwolle',
#  'taillierter schnitt',
#  'lockerer schnitt',
#  'materialkonstruktion:\xa0jersey',
#  'details:\xa0elastischer bund',
#  'baumwolle',
#  'gerader schnitt',
#  'verschluss:\xa0verdeckter zip-fly',
#  'nicht trockner geeignet',
#  'leibhöhe:\xa0normal',
#  'ärmellänge:\xa0extralanger arm',
#  'hosentaschen:\xa0gesäßtaschen',
#  'material oberstoff:\xa0100% polyester',
#  'seitentaschen',
#  'materialkonstruktion:\xa0sweat',
#  'länge:\xa0lang',
#  'leibhöhe:\xa0hoch',
#  'muster:\xa0print',
#  'label patch/label flag',
#  'länge:\xa0kurz',
#  '5-pocket-style',
#  'verschluss:\xa0reißverschluss',
#  'seitliche eingrifftaschen',
#  'ärmellänge:\xa0kurzarm',
#  'pflegehinweise:\xa0maschinenwäsche bei 30°c',
#  'fließender stoff',
#  'verschluss:\xa0knopf',
#  'länge:\xa0knöchellang',
#  '5% elasthan',
#  'gürtelschlaufen',
#  'länge: kurz/mini',
#  'viskose',
#  'elastischer bund/saum',
#  'jeans',
#  'futter:\xa0100% polyester',
#  'muster:\xa0meliert',
#  'passform:\xa0tailliert',
#  'kragenlos',
#  'materialart: feinstrick',
#  'transparenz:\xa0leicht',
#  'v-ausschnitt',
#  'rippbündchen',
#  'länge:\xa0knielang',
#  'materialkonstruktion:\xa0denim',
#  'kragen:\xa0kapuze',
#  'rundhalsausschnitt',
#  'glatter stoff',
#  'blusenshirt',
#  'runder saum',
#  'leicht transparent',
#  'knopfleiste',
#  'reißverschluss',
#  'muster:\xa0geblümt',
#  'hosentaschen:\xa0seitentaschen',
#  'länge:\xa0extra kurz',
#  'maximales einlaufen 5%',
#  '2% elasthan',
#  'details:\xa0eingrifftaschen',
#  'ärmellänge: viertelarm',
#  'passform:\xa0weit geschnitten',
#  'stehkragen',
#  'elastizität: elastisch/stretch',
#  'modelgröße:\xa0unser model ist 178 cm groß und trägt größe 36',
#  'geblümt/floral',
#  'applikationen',
#  'länge: lang/maxi',
#  'modelgröße:\xa0unser model ist 178 cm groß und trägt größe s',
#  'obermaterial: 100 % polyester',
#  '3% elasthan',
#  'muster:\xa0gestreift',
#  'material oberstoff:\xa0100% viskose',
#  'passform: lockere passform',
#  'länge: knielang',
#  'ärmellänge: ärmellos',
#  'unser model ist 177 cm groß und trägt größe 36.',
#  'ärmellänge: dreiviertelarm',
#  'passform:\xa0schmal',
#  'spitze',
#  'verlängerte rückenpartie',
#  'pflegehinweise:\xa0handwäsche',
#  'details kapuze:\xa0kapuze mit tunnelzug',
#  'gestreift',
#  '2 % elasthan',
#  'ärmellänge:\xa0ärmellos',
#  'waschungseffekt',
#  'ärmellänge:\xa0dreiviertelarm',
#  'futter: 100 % polyester',
#  'ausschnitt:\xa0tiefer v-ausschnitt',
#  'ausgestellter schnitt',
#  'überschnittene schulter',
#  'länge:\xa07/8 länge',
#  'leibhöhe: mid waist',
#  'drapiert/gerafft',
#  'label plate',
#  'nicht bügeln',
#  'leicht gefüttert',
#  '5 % elasthan',
#  'volant',
#  'leichter stoff',
#  'zum knoten/binden',
#  'zip fly',
#  'keyholeverschluss',
#  'obermaterial: 100 % baumwolle',
#  'modelgröße:\xa0unser model ist 180 cm groß und trägt größe s',
#  'modelgröße:\xa0unser model ist 180 cm groß und trägt größe 36',
#  'details:\xa0reißverschluss',
#  'farbe schwarz',
#  'eingefasster ausschnitt',
#  '4% elasthan',
#  'materialmix',
#  'rücken-reißverschluss',
#  'modelgröße:\xa0unser model ist 176 cm groß und trägt größe s',
#  'chemische reinigung möglich',
#  'passform:\xa0tapered leg',
#  'details:\xa0brustabnäher',
#  'normaler träger',
#  'länge:\xa0oberschenkellang',
#  'modelgröße:\xa0unser model ist 177 cm groß und trägt größe s',
#  'teilungsnähte',
#  'elastischer bund',
#  'falten',
#  'seitliche schlitze',
#  'passform:\xa0körpernah',
#  'passform: figurbetonte passform',
#  'seitliche reißverschlusstaschen',
#  'nichttextile teile tierischen ursprungs:\xa0ja',
#  'reine baumwolle',
#  'kunstlederdetails',
#  '3 % elasthan',
#  'obermaterial: 100 % viskose',
#  'modelgröße:\xa0unser model ist 177 cm groß und trägt größe 36',
#  'kragen:\xa0stehkragen',
#  'passform: skinny',
#  'modelgröße:\xa0unser model ist 176 cm groß und trägt größe 36',
#  'pflegehinweise:\xa0chemische reinigung',
#  'used-look',
#  'materialkonstruktion:\xa0ripp',
#  'raglanärmel',
#  'unser model ist 177 cm groß und trägt größe s.',
#  'kapuze mit tunnelzug',
#  'strukturierte oberfläche',
#  'material oberstoff:\xa098% baumwolle',
#  'passform:\xa0slim fit',
#  'breiter träger',
#  'gesäßtaschen',
#  'mit band/kordel',
#  'ärmellänge:\xa0halbarm',
#  'brusttasche',
#  'details:\xa0gürtel inklusive',
#  'klassische bluse',
#  'modelgröße:\xa0unser model ist 179 cm groß und trägt größe s',
#  'used look',
#  'material oberstoff:\xa065% baumwolle',
#  'stickerei',
#  'nachhaltigkeit',
#  'knopfverschluss',
#  'länge: langer schnitt',
#  '35% polyester',
#  'material: 100 % baumwolle',
#  'knopf- und reißverschluss',
#  'rüschen',
#  'länge:\xa0wadenlang',
#  'motivprint',
#  'angedeutete gesäßtaschen',
#  'ohne verschluss',
#  'kühler griff',
#  'chiffon',
#  'passform:\xa0flare',
#  'tiefer ausschnitt/dekolleté',
#  'warm gefüttert',
#  '50% baumwolle',
#  'kentkragen',
#  'passform:\xa0skinny',
#  '1-knopf-manschetten',
#  'material: 100 % polyester',
#  'passform:\xa0straight leg',
#  '5\xa0cm',
#  'umlegekragen',
#  'angeschnittene ärmel',
#  'passform: schmale passform',
#  'material: 100 % viskose',
#  'cut-outs',
#  'necktape',
#  'material oberstoff:\xa095% polyester',
#  'verdeckter reißverschluss',
#  'kontrastnähte',
#  'materialart: grobstrick',
#  'material oberstoff:\xa050% polyester',
#  'farbe marineblau',
#  'melange',
#  'wickeloptik',
#  'ausschnitt:\xa0rückenausschnitt',
#  'eingrifftaschen',
#  'modelgröße:\xa0unser model ist 179 cm groß und trägt größe 36',
#  'rückenausschnitt',
#  'taillentunnelzug',
#  'logoprint',
#  'unterkleid',
#  '1% elasthan',
#  'umweltfreundliche materialien',
#  'details:\xa0unterkleid',
#  'steppungen',
#  'ausschnitt:\xa0v-ausschnitt',
#  'fester griff',
#  'glitzernd',
#  'ziersteine',
#  'synthetik',
#  'stark transparente partien',
#  'passform: slimfit',
#  'material oberstoff:\xa097% baumwolle',
#  'label print',
#  'material oberstoff:\xa060% baumwolle',
#  '6% elasthan',
#  'spaghettiträger',
#  'leicht taillierter schnitt',
#  'farbe dunkelblau',
#  'wird offen und ohne verschluss getragen',
#  'ungefüttert',
#  'farbe weiß',
#  'label-stickerei',
#  'länge: 7/8-lang',
#  'länge:\xa0extra lang',
#  'unser model ist 177 cm groß.',
#  'nieten',
#  'ärmellänge: halbarm',
#  'taillenbund',
#  'druckknopfleiste',
#  'schulterfrei/off-shoulder',
#  'brustabnäher',
#  'ärmellänge:\xa0spaghettiträger',
#  'materialkonstruktion:\xa0spitze',
#  'baumwoll-elasthan-mix',
#  'gepunktet',
#  'glänzend',
#  'bund mit tunnelzug',
#  'baumwollmischung mit stretch-anteil',
#  'lagenlook',
#  'muster:\xa0gepunktet',
#  'obermaterial: 98 % baumwolle',
#  'rippstrick',
#  '1 % elasthan',
#  'reine viskose',
#  'ärmelaufschlag',
#  'überschnittene schultern',
#  'bündchen-/rippstrick-kragen',
#  'metallösen',
#  'u-boot-ausschnitt',
#  'modelgröße:\xa0unser model ist 174 cm groß und trägt größe s',
#  'verdeckte knopfleiste',
#  'verschluss:\xa0zip-fly',
#  'mit unterkleid',
#  'ausschnitt:\xa0carmen',
#  'unser model ist 177 cm groß und trägt größe m.',
#  'trompetenärmel',
#  'kragen:\xa0reverskragen',
#  '40% polyester',
#  'tunnelzug im saum',
#  'kontrastfarbene einsätze',
#  'a-linie',
#  'transparenz:\xa0stark',
#  'ausschnitt:\xa0cache-coeur',
#  'light washed',
#  'aufgesetzte taschen',
#  'nahtreißverschluss auf der rückseite',
#  'ärmellänge:\xa0extrakurzer arm',
#  'breiter bund',
#  'material oberstoff:\xa095% baumwolle',
#  'tunnelzug im bund',
#  'tunika-ausschnitt',
#  'kragen:\xa0hemdblusenkragen',
#  '4 % elasthan',
#  'steppjacke',
#  'rückennaht',
#  'ausschnitt:\xa0tiefer rundhals',
#  'futter:\xa0100% baumwolle',
#  'weiter ausschnitt',
#  'gesamtlänge:\xa060 cm bei größe s',
#  'handwäsche',
#  'baumwollmischung',
#  'patten-/klappentaschen',
#  'zwei eingrifftaschen',
#  'pailletten',
#  'material oberstoff:\xa095% viskose',
#  'innentasche',
#  'details:\xa0fransen',
#  'streifenmuster',
#  'taschen:\xa0pattentaschen',
#  'modelgröße:\xa0unser model ist 175 cm groß und trägt größe s',
#  'passform: regular',
#  'strukturierter griff',
#  'leder',
#  'gesamtlänge:\xa062 cm bei größe s',
#  'ziernaht',
#  'offene kanten',
#  'elastikeinsätze',
#  'ausgestellter rockteil',
#  'muster:\xa0kariert',
#  'mottoprint',
#  'ärmellos',
#  'lochmuster',
#  'ärmellänge:\xa065 cm bei größe s',
#  'fransen',
#  'ärmellänge:\xa064 cm bei größe s',
#  'gürtel inklusive',
#  'leibhöhe: low waist',
#  'mit kapuze',
#  'blickdichtes unterkleid',
#  'schlupfbluse',
#  'gehschlitz',
#  'destroyed',
#  'leibhöhe: high waist',
#  'ärmellänge:\xa062 cm bei größe s',
#  'heavy washed',
#  'bikerjacke',
#  'farbe jeans',
#  'gerippter rundhalsausschnitt',
#  'saum/kante mit borte',
#  'rückenfalte',
#  'gesamtlänge:\xa061 cm bei größe s',
#  'lederpatch am bund',
#  'fransensaum',
#  'ärmellänge:\xa063 cm bei größe s',
#  'passform:\xa0oversized',
#  'schimmernd',
#  'seitlicher reißverschluss',
#  'ausschnitt:\xa0u-boot',
#  'unterrock',
#  'farbe offwhite',
#  'rollsaum',
#  'kragen:\xa0umlegekragen',
#  'taillengürtel',
#  'futter: 100 % baumwolle',
#  'florales muster',
#  'softfinish innen',
#  'gesamtlänge:\xa058 cm bei größe s',
#  'material oberstoff:\xa065% polyester',
#  'gesamtlänge:\xa063 cm bei größe s',
#  'sweatstoff',
#  'material oberstoff:\xa097% polyester',
#  'modelgröße:\xa0unser model ist 175 cm groß und trägt größe 36',
#  'futter:\xa0100% viskose',
#  'eng anliegender schnitt',
#  '35 % baumwolle',
#  'taschen:\xa0mit reißverschluss verschließbare taschen',
#  'gesamtlänge:\xa065 cm bei größe s',
#  'münztasche',
#  'details:\xa0unterrock',
#  'reißverschluss auf der rückseite',
#  'schnürung',
#  'obermaterial: 95 % polyester',
#  'transparent',
#  'gesamtlänge:\xa059 cm bei größe s',
#  'lange ärmel',
#  'stone washed',
#  'verstellbare träger',
#  '8% elasthan',
#  'dreiviertel-ärmel',
#  'gerade manschetten',
#  '20% polyester',
#  'details:\xa0knopfleiste',
#  'fütterungsdicke:\xa0ungefüttert',
#  'gefütterte kapuze',
#  'geknöpfter schlüssellochausschnitt auf der rückseite',
#  'rückenbreite:\xa038 cm bei größe 36',
#  'luftiger stoff',
#  'obermaterial: 100 % leder',
#  'passform:\xa0loose fit',
#  'paspel-/leistentaschen',
#  'kragen:\xa0hochabschließender kragen',
#  'material oberstoff:\xa0100% lyocell',
#  'rückenbreite:\xa037 cm bei größe 36',
#  'gesamtlänge:\xa064 cm bei größe s',
#  '35% baumwolle',
#  'länge: kurzer schnitt',
#  'mit gürtel',
#  'kurze ärmel',
#  'farbe rot',
#  'label-patch',
#  'feiner stoff',
#  'ärmellänge:\xa066 cm bei größe s',
#  'kurze',
#  'kontrastfutter',
#  'seitliche streifen',
#  'länge: 3/4-lang',
#  'ärmellänge:\xa061 cm bei größe s',
#  'colored denim',
#  'bügelfalten',
#  'material oberstoff:\xa099% baumwolle',
#  'skinny fit',
#  'perlmuttknöpfe',
#  'kängurutasche',
#  'a-linien-rock',
#  'netz-/mesheinsätze',
#  'ärmellänge:\xa060 cm bei größe s',
#  'carmen-ausschnitt',
#  'allover-muster',
#  'gerippte abschlüsse',
#  'druckknopfverschluss',
#  'leibhöhe:\xa0niedrig',
#  'modelgröße:\xa0unser model ist 174 cm groß und trägt größe 36',
#  'ärmellänge:\xa067 cm bei größe s',
#  'verschluss:\xa0schnürung',
#  'slim fit',
#  'rollkragen',
#  'kariert',
#  'taillierter',
#  'oversized',
#  'ärmellänge:\xa062 cm bei größe 36',
#  'destroyed-effekte',
#  'länge:\xa03/4 länge',
#  'material oberstoff:\xa080% baumwolle',
#  'französische eingrifftaschen',
#  '6 % elasthan',
#  'rückenbreite:\xa036 cm bei größe 36',
#  'leichtes material',
#  'blue denim/washed',
#  'verschluss:\xa0button-fly',
#  'elastisches material',
#  'zweiwege-reißverschluss',
#  'asymmetrischer saum',
#  'rückenbreite:\xa039 cm bei größe 36',
#  '30% polyester',
#  'schalkragen',
#  'material oberstoff:\xa0100% polyacryl',
#  'gesamtlänge:\xa060 cm bei größe 36',
#  'ärmelloser schnitt',
#  'gesamtlänge:\xa056 cm bei größe s',
#  'gesamtlänge:\xa057 cm bei größe s',
#  'ärmel-reißverschluss',
#  'waschungseffekte',
#  '7% elasthan',
#  'plus size',
#  'schräger reißverschluss',
#  'cotton made in africa',
#  'unser model ist 177 cm groß und trägt größe 34.',
#  '2er pack',
#  'material oberstoff:\xa050% baumwolle',
#  'mit schmucksteinen',
#  'leicht transparente partien',
#  'coloured denim',
#  'obermaterial: 100 % nylon',
#  'modelgröße:\xa0unser model ist 182 cm groß und trägt größe 36',
#  'modelgröße:\xa0unser model ist 181 cm groß und trägt größe 36',
#  'ärmellänge:\xa063 cm bei größe 36',
#  'gesamtlänge:\xa062 cm bei größe 36',
#  'material oberstoff:\xa096% polyester',
#  'füllung: 100 % polyester',
#  'two tone',
#  'obermaterial: 95 % viskose',
#  'reverskragen',
#  '10% elasthan',
#  'gesamtlänge:\xa066 cm bei größe s',
#  'wasserabweisend',
#  'raw/unwashed',
#  'material oberstoff:\xa094% polyester',
#  '8 % elasthan',
#  '2-knopf-manschetten',
#  'obermaterial: 50 % baumwolle',
#  'turn-up-ärmel',
#  'material oberstoff:\xa050% polyacryl',
#  'fein strukturiertes material',
#  '20 % nylon',
#  'paspelierung',
#  'ärmellänge:\xa068 cm bei größe s',
#  'flammgarn-struktur',
#  'regenjacke',
#  'lederimitat',
#  'rückenbreite:\xa040 cm bei größe 36',
#  'rinsed/dark washed',
#  'details aus kunstleder',
#  'eingefasster saum/kante',
#  'material oberstoff:\xa080% viskose',
#  'details:\xa0längenverstellbare träger',
#  'material oberstoff:\xa055% baumwolle',
#  'zwei reißverschlusstaschen',
#  'schnitt:\xa0asymmetrisch',
#  'rückenschlitz',
#  'material oberstoff:\xa070% baumwolle',
#  'material oberstoff:\xa070% viskose',
#  'flammgarn',
#  'angedeutete taschen',
#  'ärmellänge:\xa064 cm bei größe 36',
#  'tunnelzug auf taillenhöhe',
#  'viskosemischung mit stretch-anteil',
#  'gesamtlänge:\xa063 cm bei größe 36',
#  'ärmelfutter: 100 % polyester',
#  'wolle',
#  'farbe rosé',
#  'aufgesetzte knopfleiste',
#  'musterstrick',
#  'wattierte cups',
#  'ärmellänge:\xa060 cm bei größe 36',
#  '50 % polyacryl',
#  'gesamtlänge:\xa061 cm bei größe 36',
#  'farbe rosa',
#  'schmal zulaufendes bein',
#  'seidiger griff',
#  'material: 98 % baumwolle',
#  'ärmellänge:\xa061 cm bei größe 36',
#  'farbe pink',
#  'gesamtlänge:\xa067 cm bei größe s',
#  '45% polyester',
#  '28% polyester',
#  'viskosemischung',
#  'figurformend',
#  'futter:\xa095% polyester',
#  '50% modal',
#  '25% polyester',
#  'gesamtlänge:\xa065 cm bei größe 36',
#  'material oberstoff:\xa0100% leinen',
#  'rückenlänge bei größe s: 60\xa0cm',
#  'rückenbreite:\xa038 cm bei größe s',
#  'umgeschlagener saum',
#  'hakenverschluss',
#  'obermaterial: 99 % baumwolle',
#  'material oberstoff:\xa065% viskose',
#  'high-low-saum',
#  'material oberstoff:\xa096% baumwolle',
#  'seitenschlitze',
#  '20% nylon',
#  'kapuze mit abnehmbaren kunstfellbesatz',
#  'mehrere farben pro pack',
#  'gesamtlänge:\xa059 cm bei größe 36',
#  'rückenlänge bei größe 36: 60\xa0cm',
#  'feinstrick',
#  'gesamtlänge:\xa070 cm bei größe s',
#  'bleistiftrock',
#  'schößchen',
#  'ärmellänge:\xa065 cm bei größe 36',
#  '6 % polyester',
#  'plissee',
#  'gesamtlänge:\xa055 cm bei größe s',
#  'gesamtlänge:\xa068 cm bei größe s',
#  'gesamtlänge:\xa058 cm bei größe 36',
#  'logo-applikation',
#  '40 % polyester',
#  'fütterungsdicke:\xa0leicht gefüttert',
#  'rückenbreite:\xa035 cm bei größe 36',
#  'material füllung:\xa0100% polyester',
#  '35% viskose',
#  'rückenbreite:\xa040 cm bei größe s',
#  'materialkonstruktion:\xa0kunstleder',
#  'material oberstoff:\xa0100% wolle',
#  'material oberstoff:\xa092% baumwolle',
#  'nichttextile teile tierischen ursprungs:\xa0nein',
#  'gesamtlänge:\xa064 cm bei größe 36',
#  'material oberstoff:\xa098% polyester',
#  'strapazierfähiges material',
#  'rückenbreite:\xa037 cm bei größe s',
#  'ärmellänge:\xa070 cm bei größe s',
#  'gesamtlänge:\xa056 cm bei größe 36',
#  'material oberstoff:\xa096% viskose',
#  'offene vorderseite',
#  'geschlitzter ausschnitt',
#  'ärmellänge:\xa069 cm bei größe s',
#  'rückenlänge bei größe 36: 95\xa0cm',
#  'ausschnitt:\xa0karree',
#  'passform:\xa0oberbauch',
#  'echtlederpatch am bund',
#  'fütterungsdicke:\xa0warm gefüttert',
#  'logo-print',
#  'daune',
#  'kapuze mit stehkragen',
#  'obermaterial: 92 % baumwolle',
#  '33% viskose',
#  'modelgröße:\xa0unser model ist 180 cm groß und trägt größe m',
#  'fransen/tasseln',
#  'destroyed look',
#  'schulterriegel',
#  'abgesetzter',
#  'modelgröße:\xa0unser model ist 178 cm groß und trägt größe 27',
#  '45% baumwolle',
#  'gesamtlänge:\xa054 cm bei größe s',
#  'farbe hellblau',
#  '20 % polyester',
#  'krepp',
#  '20% baumwolle',
#  'blouson',
#  'mesh',
#  '20% polyamid',
#  'modelgröße:\xa0unser model ist 180 cm groß und trägt größe 38',
#  'rückenbreite:\xa034 cm bei größe 36',
#  'material oberstoff:\xa060% viskose',
#  'abnehmbare kapuze',
#  'modelgröße:\xa0unser model ist 178 cm groß und trägt größe m',
#  'kragen:\xa0rollkragen',
#  'polokragen',
#  '10 % elasthan',
#  'weich angeraute innenseite',
#  'leinen',
#  'gesamtlänge:\xa069 cm bei größe s',
#  'melangeoptik',
#  'elastizität: hochelastisch/superstretch',
#  '40% baumwolle',
#  'material oberstoff:\xa075% baumwolle',
#  'gesamtlänge:\xa066 cm bei größe 36',
#  'material oberstoff:\xa063% polyester',
#  'satin',
#  'gelegte falten',
#  '26 % polyamid',
#  'rückenlänge bei größe s: 62\xa0cm',
#  '15% polyester',
#  'zusammensetzung: 100 % polyester',
#  'obermaterial: 70 % viskose',
#  'modelgröße:\xa0unser model ist 163 cm groß und trägt größe 36',
#  'ausschnitt:\xa0henley',
#  'washed look',
#  'gesamtlänge:\xa067 cm bei größe 36',
#  '45% viskose',
#  'material oberstoff:\xa052% baumwolle',
#  'reißverschlusstasche',
#  'längenverstellbare träger',
#  '30 % polyester',
#  'kastiger schnitt',
#  'material oberstoff:\xa093% baumwolle',
#  'materialmischung mit viskose-anteil',
#  'modelgröße:\xa0unser model ist 178 cm groß und trägt größe 38',
#  'ärmellänge bei größe 36: 62\xa0cm',
#  '32% polyester',
#  'wattierung: 100 % polyester',
#  'modelgröße:\xa0unser model ist 181 cm groß und trägt größe s',
#  'gesamtlänge:\xa090 cm bei größe 36',
#  'innenliegende tasche',
#  'obermaterial: 65 % polyester',
#  'farbe blau',
#  'teilweise stark transparente partien',
#  'zusammensetzung: 100 % baumwolle',
#  'verstellbare kapuze',
#  'gesamtlänge:\xa057 cm bei größe 36',
#  'raffungen',
#  'wellensaum',
#  'gesamtlänge:\xa053 cm bei größe s',
#  'griffiger stoff',
#  'obermaterial: 97 % baumwolle',
#  'elastischer saum',
#  'ethno-muster',
#  'mit unterrock',
#  'rückenbreite:\xa039 cm bei größe s',
#  'trockenreinigung',
#  'made in europe',
#  'unser model ist 177 cm groß und trägt größe 27.',
#  'ärmellänge:\xa059 cm bei größe s',
#  'obermaterial: 100 % polyacryl',
#  '20% viskose',
#  'gesamtlänge:\xa055 cm bei größe 36',
#  'angedeutete seitentaschen',
#  'seide',
#  'chemische reinigung',
#  '30% polyamid',
#  'stickereien',
#  '35% polyamid',
#  '28 % polyester',
#  'obermaterial: 97 % polyester',
#  'kragen:\xa0schalkragen',
#  'obermaterial: 95 % baumwolle',
#  'obermaterial: 80 % viskose',
#  'leicht ausgestellter schnitt',
#  'fledermausärmel',
#  'lockerer',
#  'farbe hellgrau meliert',
#  'button fly',
#  '10 % feder',
#  'passform: loosefit',
#  'ärmellänge:\xa066 cm bei größe 36',
#  'modelgröße:\xa0unser model ist 182 cm groß und trägt größe s',
#  'verschluss:\xa0gürtel',
#  'materialkonstruktion:\xa0fleece',
#  '30% viskose',
#  'material oberstoff:\xa050% viskose',
#  'material: 95 % viskose',
#  'rückenlänge bei größe 36: 62\xa0cm',
#  'fleece-futter',
#  'material oberstoff:\xa0100% leder',
#  'gesamtlänge:\xa068 cm bei größe 36',
#  'animalprint',
#  '30% nylon',
#  '30 % nylon',
#  'lange raglanärmel',
#  'lammleder',
#  'gesamtlänge:\xa090 cm bei größe s',
#  '50% viskose',
#  'verstellbare bundweite',
#  'material oberstoff:\xa0100% polyamid',
#  'material oberstoff:\xa090% baumwolle',
#  'material oberstoff:\xa092% polyester',
#  'material oberstoff:\xa090% polyester',
#  'material oberstoff:\xa0100% kaschmir',
#  'material oberstoff:\xa085% baumwolle',
#  'material: 95 % polyester',
#  'elastischer bund mit tunnelzug',
#  'knopf-',
#  'passform: weite passform',
#  'rippenstruktur',
#  '20 % baumwolle',
#  'hosensaum mit reißverschluss',
#  'mit stark transparenten partien',
#  'leichtes unterkleid',
#  'ziernähte',
#  'gesamtlänge:\xa092 cm bei größe 36',
#  'knöpfbare ärmel',
#  'rückenlänge bei größe m: 60\xa0cm',
#  'kragen:\xa0rundhals',
#  'rückenbreite:\xa036 cm bei größe s',
#  'slub jersey',
#  'kurze knopfleiste',
#  'geschmeidiger griff',
#  'patches',
#  'obermaterial: 60 % baumwolle',
#  'obermaterial: 100 % polyamid',
#  'beininnenlänge:\xa072 cm bei größe 36',
#  'material oberstoff:\xa0100% seide',
#  '32% viskose',
#  'kappärmel',
#  'tiefer rückenausschnitt',
#  '50 % baumwolle',
#  'obermaterial: 74 % baumwolle',
#  'details kapuze:\xa0abnehmbare kapuze',
#  'label-patch am bund',
#  '6% polyester',
#  'haken- und reißverschluss',
#  '30% baumwolle',
#  'gesamtlänge:\xa052 cm bei größe s',
#  'gesamtlänge:\xa070 cm bei größe 36',
#  'cropped',
#  '30 % polyamid',
#  'gesamtlänge:\xa095 cm bei größe 36',
#  'viskose-elasthan-mix',
#  '20 % polyamid',
#  'material oberstoff einsatz:\xa0100% polyester',
#  'futter:\xa065% polyester',
#  'rückenlänge bei größe 36: 58\xa0cm',
#  '25 % polyester',
#  'wetter:\xa0regen',
#  'futter: 100 % viskose',
#  'rückenlänge bei größe s: 58\xa0cm',
#  'material: 50 % baumwolle',
#  'rückenlänge bei größe s: 61\xa0cm',
#  '35 % viskose',
#  'ärmellänge:\xa058 cm bei größe s',
#  'haken- und nahtreißverschluss auf der rückseite',
#  'material oberstoff:\xa074% baumwolle',
#  'gesamtlänge:\xa072 cm bei größe s',
#  '50 % polyester',
#  '27% polyester',
#  '10% polyester',
#  'ausgestellter rockteil mit raffungen',
#  'rückenlänge bei größe 36: 64\xa0cm',
#  'label-prägung',
#  'schulterpolster',
#  'fixierte beinumschläge',
#  'taschen:\xa0innenliegende tasche',
#  'leicht verlängerte rückseite',
#  'bomberjacke',
#  'material oberstoff:\xa064% polyester',
#  'logo-stickerei',
#  'material oberstoff:\xa055% leinen',
#  'gesamtlänge:\xa093 cm bei größe 36',
#  'material oberstoff:\xa055% polyester',
#  'materialmischung mit stretch-anteil',
#  'material oberstoff:\xa063% viskose',
#  'rückenlänge bei größe 36: 90\xa0cm',
#  'farbe bordeaux rot',
#  'obermaterial: 100 % lyocell',
#  'extra lange ärmel',
#  'material oberstoff:\xa094% baumwolle',
#  'beininnenlänge:\xa070 cm bei größe 36',
#  'abgerundeter v-ausschnitt',
#  '23% polyester',
#  'sportart:\xa0fitness',
#  'nicht waschen',
#  'unser model ist 177\xa0cm groß und trägt größe 36.',
#  'ärmellänge:\xa059 cm bei größe 36',
#  '35 % polyester',
#  'modelgröße:\xa0unser model ist 165 cm groß und trägt größe 36',
#  'muster:\xa0animal print',
#  'modelgröße:\xa0unser model ist 180 cm groß und trägt größe 27',
#  '40 % baumwolle',
#  'obermaterial: 5 % elasthan',
#  '23 % polyester',
#  'kapuze mit kunstfellbesatz',
#  'beschichtet',
#  'obermaterial: 50 % polyacryl',
#  'passform:\xa0regular fit',
#  '7 % elasthan',
#  'zierleisten am gesäß',
#  'beininnenlänge:\xa074 cm bei größe 36',
#  'pattentaschen',
#  'beininnenlänge:\xa071 cm bei größe 36',
#  '45 % viskose',
#  'beinaußenlänge:\xa095 cm bei größe 36',
#  'mit kunstlederdetails',
#  'ärmellänge bei größe s: 62\xa0cm',
#  'modelgröße:\xa0unser model ist 177 cm groß und trägt größe 27',
#  'volantbesatz',
#  'rückenbreite:\xa033 cm bei größe 36',
#  'passform: bootcut',
#  'racerback',
#  '5-pocket style',
#  'off shoulder',
#  'modelgröße:\xa0unser model ist 176 cm groß und trägt größe 27',
#  'bio-baumwolle',
#  'rippstrickbündchen',
#  '31% polyester',
#  'material oberstoff:\xa072% viskose',
#  'robuster stoff',
#  'obermaterial: 100 % polyurethan',
#  'angedeutete gesäßtasche',
#  'material: 65 % polyester',
#  '',
#  'material oberstoff:\xa057% baumwolle',
#  'ärmellänge:\xa067 cm bei größe 36',
#  'gesamtlänge:\xa050 cm bei größe 36',
#  '24 % polyester',
#  'futter: 100 % nylon',
#  'gesamtlänge:\xa086 cm bei größe s',
#  'gesamtlänge:\xa087 cm bei größe s',
#  'gesamtlänge:\xa088 cm bei größe 36',
#  'gesamtlänge:\xa089 cm bei größe 36',
#  'gesamtlänge:\xa094 cm bei größe 36',
#  '18% viskose',
#  'details:\xa0troddeln',
#  'fully fashioned',
#  'karree-ausschnitt',
#  'material oberstoff:\xa062% polyester',
#  'mit kristallperlen/glasperlen',
#  'schluppe',
#  'gesamtlänge:\xa096 cm bei größe 36',
#  'material oberstoff:\xa068% polyester',
#  'verschluss:\xa0haken',
#  'beininnenlänge:\xa067 cm bei größe 36',
#  'pflegehinweise:\xa0lederspezialreinigung',
#  'weite ärmelausschnitte',
#  'beininnenlänge:\xa068 cm bei größe 36',
#  'ärmellänge bei größe 36: 63\xa0cm',
#  'logo-applikationen',
#  'material oberstoff:\xa070% polyester',
#  'rückenlänge bei größe s: 64\xa0cm',
#  'piqué',
#  '24% polyester',
#  '17% polyester',
#  'material oberstoff:\xa080% polyester',
#  'material oberstoff:\xa060% polyester',
#  '9% elasthan',
#  'material oberstoff:\xa0100% nylon',
#  'mit windschutzblende',
#  '22% polyester',
#  'rückenlänge bei größe 36: 150\xa0cm',
#  'modelgröße:\xa0unser model ist 176 cm groß und trägt größe 38',
#  'ärmellänge:\xa0schulterfrei',
#  'gesamtlänge:\xa080 cm bei größe s',
#  'material oberstoff:\xa075% viskose',
#  'florale stickereien',
#  'gesamtlänge:\xa098 cm bei größe 36',
#  '25% polyamid',
#  '5% polyester',
#  'beinaußenlänge:\xa093 cm bei größe 36',
#  '30 % baumwolle',
#  '18% polyester',
#  'ärmellänge:\xa068 cm bei größe 36',
#  'gesamtlänge:\xa050 cm bei größe s',
#  '30 % viskose',
#  '34% viskose',
#  'gesamtlänge:\xa054 cm bei größe 36',
#  'füllung: 90 % daunen',
#  'material oberstoff:\xa094% viskose',
#  'teilweise stark transparent',
#  'material: 80 % viskose',
#  'gesamtlänge:\xa069 cm bei größe 36',
#  'gesamtlänge:\xa053 cm bei größe 36',
#  '1/2-arm',
#  'wollwaschgang',
#  'zusätzlicher hakenverschluss',
#  'größenhinweis: fällt etwas kleiner aus',
#  'material oberstoff:\xa063% baumwolle',
#  'unser model ist 177 cm groß und trägt größe 42.',
#  '35 % nylon',
#  'rückenlänge bei größe 36: 65\xa0cm',
#  'rückenbreite:\xa032 cm bei größe 36',
#  'taillengürtel zum binden',
#  '40% viskose',
#  '15 % polyester',
#  '8% polyester',
#  '27 % nylon',
#  '12% elasthan',
#  'farbe anthrazit',
#  '28% viskose',
#  'materialart: jersey/trikot',
#  'biesen',
#  'rückenlänge bei größe s: 59\xa0cm',
#  'lochstrick',
#  'seitlicher nahtreißverschluss',
#  '25 % nylon',
#  'tunnelzug im hosenbund',
#  'material: 74 % baumwolle',
#  'farbe mittelgrau',
#  'ärmellänge bei größe 36: 60\xa0cm',
#  'material: 97 % baumwolle',
#  'gesamtlänge:\xa071 cm bei größe s',
#  '26% polyester',
#  'rundhalsausschnitt mit eingesetztem v-ausschnitt',
#  'langer schnitt',
#  '50 % viskose',
#  'beinaußenlänge:\xa097 cm bei größe 36',
#  'beininnenlänge:\xa073 cm bei größe 36',
#  '16% polyamid',
#  'beininnenlänge:\xa069 cm bei größe 36',
#  'material oberstoff:\xa069% baumwolle',
#  '7% polyester',
#  'gesamtlänge:\xa097 cm bei größe 36',
#  '17 % polyester',
#  'beinaußenlänge:\xa096 cm bei größe 36',
#  'gesamtlänge:\xa088 cm bei größe s',
#  'beinaußenlänge:\xa094 cm bei größe 36',
#  'ärmellänge bei größe s: 63\xa0cm',
#  'muster:\xa0bunt',
#  'muster:\xa0camouflage',
#  'muster:\xa0nadelstreifen',
#  'neckholder',
#  'baumwoll-modal-mix',
#  'gesamtlänge:\xa091 cm bei größe 36',
#  'gesamtlänge:\xa052 cm bei größe 36',
#  'obermaterial: 70 % baumwolle',
#  'inside-out-nähte',
#  'modelgröße:\xa0unser model ist 178 cm groß und trägt größe 44',
#  'gesamtlänge:\xa084 cm bei größe s',
#  'ärmellänge:\xa071 cm bei größe s',
#  'futter: 100 % polyamid',
#  'gesamtlänge:\xa087 cm bei größe 36',
#  'farbe sand',
#  '27% polyamid',
#  'gesamtlänge:\xa085 cm bei größe 36',
#  'bundfalten',
#  'paisley-muster',
#  'beinaußenlänge:\xa092 cm bei größe 36',
#  'ausgefranste beinabschlüsse',
#  'rückenbreite:\xa034 cm bei größe s',
#  'farbe olivgrün',
#  'material: 60 % baumwolle',
#  'beinaußenlänge:\xa098 cm bei größe 36',
#  'farbe silber meliert',
#  'offene saumkanten',
#  'material: 100 % polyacryl',
#  'effektgarn',
#  'modelgröße:\xa0unser model ist 176 cm groß und trägt größe 44',
#  'kragen:\xa0polo',
#  'gesamtlänge:\xa051 cm bei größe 36',
#  'modelgröße:\xa0unser model ist 178 cm groß und trägt größe 27x32',
#  'obermaterial: 94 % polyester',
#  'bundweite bei größe 36: 76\xa0cm',
#  'obermaterial: 75 % baumwolle',
#  'rückenbreite:\xa042 cm bei größe 36',
#  'abgerundeter saum',
#  'gots - bio',
#  'modelgröße:\xa0unser model ist 178 cm groß und trägt größe 46',
#  '50 % modal',
#  'beinschlitz',
#  'rückenlänge bei größe m: 62\xa0cm',
#  'gesamtlänge:\xa092 cm bei größe s',
#  'rückenlänge bei größe m: 65\xa0cm',
#  'kurze seitenschlitze',
#  'gesamtlänge:\xa086 cm bei größe 36',
#  'pflegehinweise:\xa0trockenreinigung',
#  '4 % polyester',
#  'rückenlänge bei größe s: 63\xa0cm',
#  'pflegehinweise:\xa0nicht waschen',
#  'metallic-optik',
#  'rückenlänge bei größe 36: 92\xa0cm',
#  'beininnenlänge:\xa07 cm bei größe 36',
#  'farbe bleu',
#  'modelgröße:\xa0unser model ist 177 cm groß und trägt größe m',
#  '5 % polyester',
#  'gesamtlänge:\xa072 cm bei größe 36',
#  '14 % polyester',
#  'faltenrock',
#  ...]

# %% [markdown]
# ## Select useful attributes
# Find attributes that are used a lot and can be useful for the application.
# Create a special column in the dataframe with each of the useful tags.

# %%
def create_tag_column(df, tag_list, column_name):
    """ 
        Create a new column in the given dataframe with the specified column name. 
        The column holds the tag if the tag is in the tag_list otherwise it holds np.nan.
    """
    
    df[column_name] = df['tags'].apply(lambda x: [s for s in x if s in tag_list])
    df[column_name] = [x[0].split(':')[-1].strip() if len(x) > 0 else np.nan for x in df[column_name]]
    
    return df

# %% [markdown]
# ### Sleeve Length

# %%
sleeve_map = (tag_df['tag'].str.contains('ärmel') &
              ~(tag_df['tag'].str.contains('cm|größe')) & 
              (tag_df['ratio'] > 0))

# %%
sleeve_list = tag_df[sleeve_map]['tag'].tolist()
df = create_tag_column(df, sleeve_list, 'sleeve_length')

# %%
sleeve_translation = {'half': ['dreiviertel', 'halb'],
                      'short': ['kurz', 'viertel'],
                      'long': ['lang'],
                      'sleeveless': ['spaghetti', 'ärmellos']}

# %%
df['sleeve_length_en'] = df.loc[~df.sleeve_length.isnull(), 'sleeve_length'].apply(
    lambda x: translate_attributes(x, sleeve_translation))

# %%
df.groupby('sleeve_length_en')['sleeve_length'].apply(lambda x: ','.join(x.unique())).reset_index()
# Out:
#   sleeve_length_en  \
# 0             half
# 1             long
# 2            short
# 3       sleeveless
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               sleeve_length
# 0  dreiviertelarm,halbarm,raglanärmel in dreiviertel-länge,dreiviertel-ärmel mit geknöpften bündchen,dreiviertel-ärmel mit raffungen,dreiviertel-ärmel,dreiviertel-ärmel mit elastischem einsatz und raffungen,angeschnittene dreiviertel-ärmel,trompetenärmel in dreiviertel-länge,dreiviertel-ärmel mit fixiertem aufschlag,dreiviertel-ärmel mit ausgestellten abschlüssen,angeschnittene ärmel in dreiviertel-länge,dreiviertel-ärmel mit schnürung an den abschlüssen,dreiviertel-ärmel mit geschlitzten abschlüssen,leicht ausgestellte dreiviertel-ärmel,dreiviertel-ärmel mit geknöpftem abschluss,ärmel in dreiviertel-länge,raglanärmel in dreiviertel-länge mit schnürung an den abschlüssen,ballonärmel in dreiviertel-länge,glockenärmel in dreiviertel-länge,dreiviertel-ärmel mit elastischen abschlüssen,ärmel in dreiviertel-länge mit fixiertem aufschlag
# 1                                                                                          langarm,extralanger arm,extra lange ärmel,lange ärmel mit geknöpften bündchen,lange ärmel,lange ärmel mit überschnittenen schultern,lange ärmel mit elastischen bündchen,lange raglanärmel,lange ärmel mit 1-knopf-manschetten,lange ärmel mit geschlitzten abschlüssen,lange ärmel mit fixiertem aufschlag,lange ärmel mit geknöpften abschlüssen,lange ärmel aus chiffon,lange ärmel mit elastischen,lange ärmel mit 2-knopf-manschetten,lange ärmel mit gerippten abschlüssen,lange ärmel mit elastischen abschlüssen,lange ärmel mit ausgestellten abschlüssen,lange ärmel mit gesmokten abschlüssen,lange ärmel mit schnürung an den abschlüssen,lange trompetenärmel,lange ärmel mit geknöpftem abschluss,lange ärmel mit knopfverschluss,lange ärmel mit kontraststreifen
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                              viertelarm,kurzarm,extrakurzer arm,kurze ärmel mit gerippten abschlüssen,kurze ärmel,sehr kurze raglanärmel,kurze raglanärmel,kurze ärmel mit fixiertem aufschlag,sehr kurze ärmel,kurze reißverschlüsse an den ärmelabschlüssen,kurze flügelärmel,kurze trompetenärmel,lange ärmel mit kurzem reißverschluss an den abschlüssen,sehr kurze ärmel mit fixiertem aufschlag,kurze glockenärmel
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ärmellos,spaghettiträger,ärmelloser schnitt,ärmelloses unterkleid aus satin,ärmelloser,ärmelloses unterkleid,ärmelloses,ärmelloses futter

# %%
df['sleeve_length'] = df['sleeve_length_en']
df = df.drop('sleeve_length_en', axis=1)

# %% [markdown]
# ### Length

# %%
length_map = (tag_df['tag'].str.startswith('länge') &
              ~(tag_df['tag'].str.contains('cm|größe')) & 
              (tag_df['ratio'] > 0))

# %%
length_list = tag_df[length_map]['tag'].tolist()
df = create_tag_column(df, length_list, 'length')

# %%
length_translation = {'normal': ['normal', 'mittel'],
                      'knee': ['knielang'],
                      'short': ['kurz', 'oberschenkel'],
                      '3-4': ['7/8', '3/4', 'waden', 'knöchel'],
                      'long': ['lang']}

# %%
df['length_en'] = df.loc[~df.length.isnull(), 'length'].apply(
    lambda x: translate_attributes(x, length_translation))

# %%
df.groupby('length_en')['length'].apply(lambda x: ','.join(x.unique())).reset_index()
# Out:
#   length_en                                                       length
# 0       3-4  7/8 länge,knöchellang,wadenlang,7/8-lang,3/4-lang,3/4 länge
# 1      knee                                                     knielang
# 2      long                     lang/maxi,langer schnitt,lang,extra lang
# 3    normal                                         normale länge,mittel
# 4     short    kurz/mini,extra kurz,kurz,kurzer schnitt,oberschenkellang

# %%
df['length'] = df['length_en']
df = df.drop('length_en', axis=1)

# %% [markdown]
# ### Neckline

# %%
neckline_map = (tag_df['tag'].str.contains('ausschnitt') &
                tag_df['ratio'] > 0)

# %%
neckline_list = tag_df[neckline_map]['tag'].tolist()
df = create_tag_column(df, neckline_list, 'neckline')

# %%
neckline_translation = {'v': ['v-ausschnitt'],
                        'round': ['rund'],
                        'lined': ['eingefasst'],
                        'back': ['rücken'],
                        'wide': ['weit', 'carmen', 'u-boot'],
                        'deep': ['tief']
                     }

# %%
df['neckline_en'] = df.loc[~df.neckline.isnull(), 'neckline'].apply(
    lambda x: translate_attributes(x, neckline_translation))

# %%
df.groupby('neckline_en')['neckline'].apply(lambda x: ','.join(x.unique())).reset_index()
# Out:
#   neckline_en  \
# 0        back
# 1        deep
# 2       lined
# 3       round
# 4           v
# 5        wide
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   neckline
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 rückenausschnitt,tiefer rückenausschnitt
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              tiefer ausschnitt/dekolleté
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  eingefasster ausschnitt
# 3  rundhals-ausschnitt,rundhals,tiefer rundhals,rundhalsausschnitt,rundhalsausschnitt mit gerolltem abschluss,gerippter rundhalsausschnitt,breiter rundhalsausschnitt,weiter rundhalsausschnitt,gerollter rundhalsausschnitt,rundhalsausschnitt mit aussparung,rundhalsausschnitt mit gelegten falten,rundhalsausschnitt mit ziersteinbesatz,elastischer rundhalsausschnitt,rundhalsausschnitt mit zierperlenbesatz,rundhalsausschnitt mit geknöpftem schlüssellochausschnitt,rundhalsausschnitt mit gerolltem saum,rundhalsausschnitt mit raffungen,rundhalsausschnitt mit eingesetztem schlüssellochausschnitt,rundhalsausschnitt mit schnürung,rundhalsausschnitt mit hakenverschluss,rundhalsausschnitt mit metall-applikation,rundhalsausschnitt mit offenem abschluss,gerippter rundhalsausschnitt mit kontraststreifen,rundhalsausschnitt mit cut out,rundhalsausschnitt mit zierborte,rundhalsausschnitt mit cut outs,gerippter rundhalsausschnitt in kontrastfarbe,rundhalsausschnitt in wickeloptik,rundhalsausschnitt mit fe...
# 4                                                                                                                                      tiefer v-ausschnitt,v-ausschnitt,abgerundeter v-ausschnitt,rundhalsausschnitt mit eingesetztem v-ausschnitt,stehkragen mit eingesetztem v-ausschnitt,eingesetzter v-ausschnitt,v-ausschnitt in wickeloptik,gerippter v-ausschnitt,v-ausschnitt mit schluppe zum binden,v-ausschnitt mit volantbesatz,v-ausschnitt mit schnürung,v-ausschnitt auf vorder- und rückseite,v-ausschnitt auf der rückseite,eingesetzter v-ausschnitt mit schnürung,stehkragen mit eingesetztem v-ausschnitt in wickeloptik,seitlich versetzter v-ausschnitt,eingesetzter v-ausschnitt in wickeloptik,v-ausschnitt mit gewelltem abschluss,rundhalsausschnitt mit eingesetztem v-ausschnitt in wickeloptik,umlegekragen mit eingesetztem v-ausschnitt,tiefer v-ausschnitt auf vorder- und rückseite,rundhalsausschnitt und eingesetztem v-ausschnitt,abgerundeter v-ausschnitt mit gelegten falten,gerollter v-ausschnitt
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         u-boot-ausschnitt,weiter ausschnitt,carmen-ausschnitt,weite ärmelausschnitte,u-boot,carmen,u-boot ausschnitt,elastischer carmenausschnitt,gesmokter carmenausschnitt,umgelegter carmenausschnitt

# %%
df['neckline'] = df['neckline_en']
df = df.drop('neckline_en', axis=1)

# %% [markdown]
# ### Pattern

# %%
pattern_map = (tag_df['tag'].str.contains(r'floral|streif|punkt|muster|spitze|unifarben$') &
               tag_df['ratio'] > 0)

# %%
pattern_list = tag_df[pattern_map]['tag'].tolist()
df = create_tag_column(df, pattern_list, 'pattern')

# %%
pattern_translation = {'floral': ['blüm', 'floral'],
                       'polkadots': ['punkt'],
                       'stripes': ['streif'],
                       'print': ['all-over', 'meliert', 'print', 'camouflage', 'kariert', 'paisley'],
                       'lace': ['spitze'],
                       'unicolors': ['unifarben']
                      }

# %%
df['pattern_en'] = df.loc[~df.pattern.isnull(), 'pattern'].apply(
    lambda x: translate_attributes(x, pattern_translation))

# %%
df.groupby('pattern_en')['pattern'].apply(lambda x: ','.join(x.unique())).reset_index()
# Out:
#   pattern_en  \
# 0     floral
# 1       lace
# 2  polkadots
# 3      print
# 4    stripes
# 5  unicolors
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    pattern
# 0                                                                                                                                                                                                                                        geblümt/floral,geblümt,oberteil aus floraler spitze,florale stickerei,florale stickereien,florale spitze,einsatz aus floraler spitze,florale häkelspitze,oberteil aus floraler spitze mit pailletten-besatz,oberteil aus mesh mit floralen stickereien,mesh mit floralen stickereien,florales muster,florale stickereien mit ziersteinbesatz,florale stickereien mit pailletten-besatz,verstärktes bustier aus floraler spitze,florales jacquardmuster,florale zierborten,oberteil aus floraler häkelspitze,oberteil mit floralen stickereien,einsätze aus floraler spitze,florale stickereien am oberteil,locker fallendes oberteil aus floraler spitze,besatz aus floraler häkelspitze,ausgestellter rockteil mit floralem muster,florales allover-muster,floraler print,floraler spitzenbesatz
# 1                                                                                                                                                                                                                                                                                                                                   spitze,spitzenbesatz am saum,abgerundete spitze,häkelspitze,spitzenbesatz,taillenpasse aus häkelspitze,oberteil aus spitze,oberteil aus spitze mit pailletten-besatz,oberteil aus häkelspitze,ornamentale häkelspitze,stehkragen aus spitze,lochspitze,besatz aus häkelspitze,oberteil mit spitzenbesatz,einsätze aus lochspitze,einsatz aus spitze,zierborten aus häkelspitze,zierborten aus lochspitze,einsatz aus lochspitze,einsatz aus spitze auf der rückseite,einsatz aus häkelspitze,oberteil aus spitze mit ziersteinbesatz,stark transparenter spitzenbesatz,stark transparente spitzenpartie,stark transparente spitzenpartien,stark transparente spitze,stark transparenter spitzeneinsatz
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          gepunktet,punktemuster,strukturiertes punktemuster,eingewebtes punktemuster,feines punktemuster
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           all-over-muster,meliert,print,paisley-muster,fotoprint,animal print,kariert,paisley,paisleymuster,camouflage-muster,camouflage
# 4  gestreift,seitliche streifen,seitenstreifen,streifenmuster,nadelstreifen,streifenmuster in melangeoptik,zierstreifen,streifenmuster mit effektgarn,wattierte cups und silikonstreifen,silikonstreifen für sicheren halt,silikonstreifen für besseren halt,seitliche zierstreifen,feines streifenmuster,kontraststreifen,blockstreifen,eingestricktes streifenmuster,seitliche kontraststreifen,zierstreifen mit lochmuster,saum mit kontraststreifen,silikonstreifen und wattierte cups,seitliche logo-streifen,kontraststreifen an den abschlüssen,gerippter rundhalsausschnitt mit kontraststreifen,zierstreifen aus lochspitze,eingewebtes streifenmuster,wechselndes streifenmuster,logo-streifen,ringelstreifen,zierstreifen aus häkelspitze,seitliche kontraststreifen mit effektgarn,seitlicher kontraststreifen,kontraststreifen am saum,kurze kontraststreifen aus samt,strukturiertes streifenmuster,blockstreifenmuster,zierstreifen an den seiten,abgerundeter kontrastsaum mit streifenmuster,lange ärmel mit kontrasts...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                unifarben

# %%
df['pattern'] = df['pattern_en']
df = df.drop('pattern_en', axis=1)

# %% [markdown]
# ### Fit

# %%
fit_map = (tag_df['tag'].str.contains('passform| schnitt') &
          tag_df['ratio'] > 0)

# %%
fit_list = tag_df[fit_map]['tag'].tolist()
df = create_tag_column(df, fit_list, 'fit')

# %%
fit_translation = {'normal': ['gerade', 'normal', 'straight', 'regular'],
                   'loose': ['locker', 'weit', 'loose', 'oversized', 'wide'],
                   'tight': ['tailliert', 'tailiert', 'skinny', 'ausgestellt',
                             'körper', 'figur', 'eng', 'slim', 'schmal', 
                             'ausgestellt', 'jegging']
                  }

# %%
df['fit_en'] = df.loc[~df.fit.isnull(), 'fit'].apply(
    lambda x: translate_attributes(x, fit_translation))

# %%
df.groupby('fit_en')['fit'].apply(lambda x: ','.join(x.unique())).reset_index()
# Out:
#    fit_en  \
# 0   loose
# 1  normal
# 2   tight
#
#                                                                                                                                                                                                                                                                                                                                                                            fit
# 0                                                                                                                                                                                                                                                       lockerer schnitt,weite passform,weit geschnitten,oversized,lockere passform,loosefit,loose fit,wide leg,weiter schnitt
# 1                                                                                                                                                                                                                                                                                                     gerader schnitt,normale passform,regular,normal,straight leg,regular fit
# 2  taillierter schnitt,skinny,slimfit,ausgestellter schnitt,körpernah,schmal,figurbetonte passform,schmale passform,tailliert,slim fit,leicht taillierter schnitt,figurnaher schnitt,leicht ausgestellter schnitt,körpernahe passform,figurbetonter schnitt,jeggings,körperbetonter schnitt,körpernaher schnitt,eng anliegender schnitt,taillierte passform,tailierter schnitt

# %%
df['fit'] = df['fit_en']
df = df.drop('fit_en', axis=1)

# %%
df.fit.unique()
# Out:
# array(['loose', 'tight', nan, 'normal', None], dtype=object)

# %% [markdown]
# # Copy all images to new folder

# %%
data_folder = '../../../data/fashion_new/'

# %%
for idx, row in df.iterrows():
    if idx % 10000 == 0:
        print(idx)
        
    src_path = os.path.join('../../../data', row['data_path'], row['img_path'])
    
    dst_folder = os.path.join(data_folder, row['category'])
    if not os.path.exists(dst_folder):
        os.makedirs(dst_folder)
        
    dst_path = os.path.join(dst_folder, row['id'] + '.jpg')
    row['img_path'] = row['category'] + '/' + row['id'] + '.jpg'
    
    if not os.path.exists(dst_path):
        copyfile(src_path, dst_path)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000

# %%
df = df.drop(['tags', 'data_path'], axis=1)
df = df.fillna(np.nan)

# %%
df.to_csv(os.path.join(data_folder, 'data.csv'), sep=';', encoding='utf-8', index=False)

# %% [markdown]
# ## Create dummies
# Turn the created attribute columns into dummy variables.

# %%
df.columns
# Out:
# Index(['id', 'img_path', 'attributes', 'brand', 'category', 'color', 'img_url',
#        'model_img_urls', 'name', 'product_url', 'sleeve_length', 'length',
#        'neckline', 'pattern', 'fit'],
#       dtype='object')

# %%
df = df.set_index('img_path')

# %%
df_dum = pd.get_dummies(df[['category', 'color', 'length', 'pattern', 'neckline', 'sleeve_length']]).reset_index()

# %%
df_dum.tail()
# Out:
#                          img_path  category_blouses  category_dresses  \
# 92215     pants/ZX121S001-Q11.jpg                 0                 0
# 92216   jackets/ZX121U001-C11.jpg                 0                 0
# 92217   jackets/ZX121U001-Q11.jpg                 0                 0
# 92218  knitwear/ZZLGWA022-J11.jpg                 0                 0
# 92219      tops/ZZLL0K050-Q11.jpg                 0                 0
#
#        category_jackets  category_knitwear  category_pants  category_skirts  \
# 92215                 0                  0               1                0
# 92216                 1                  0               0                0
# 92217                 1                  0               0                0
# 92218                 0                  1               0                0
# 92219                 0                  0               0                0
#
#        category_tops  color_beige  color_black            ...             \
# 92215              0            0            1            ...
# 92216              0            0            0            ...
# 92217              0            0            1            ...
# 92218              0            0            0            ...
# 92219              1            0            1            ...
#
#        neckline_back  neckline_deep  neckline_lined  neckline_round  \
# 92215              0              0               0               0
# 92216              0              0               0               0
# 92217              0              0               0               0
# 92218              0              0               0               0
# 92219              0              0               0               0
#
#        neckline_v  neckline_wide  sleeve_length_half  sleeve_length_long  \
# 92215           0              0                   0                   0
# 92216           0              0                   0                   1
# 92217           0              0                   0                   1
# 92218           0              0                   0                   1
# 92219           0              0                   0                   0
#
#        sleeve_length_short  sleeve_length_sleeveless
# 92215                    0                         0
# 92216                    0                         0
# 92217                    0                         0
# 92218                    0                         0
# 92219                    0                         0
#
# [5 rows x 38 columns]

# %%
df_dum.to_csv(os.path.join(data_folder, 'img_attr.csv'), encoding='utf-8', index=False)
